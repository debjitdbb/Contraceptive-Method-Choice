# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('cmc.csv')

# %%
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:, 9-10].values

# %% [markdown]
# Splitting X and Y into train and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state=0, train_size=0.7)

# %% [markdown]
# Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Backward elimination

# %%
import statsmodels.formula.api as sm
X2 = np.append ( arr = np.ones([1472,1]).astype(int), values = X, axis = 1)

# %%
X_opt = X[:,[0,1,2,3,4,5,6,7,8]]
regressor_OLS = sm.OLS(endog = Y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     852.7
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):               0.00
# Time:                        17:58:47   Log-Likelihood:                -1840.2
# No. Observations:                1472   AIC:                             3698.
# Df Residuals:                    1463   BIC:                             3746.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0186      0.003     -6.336      0.000      -0.024      -0.013
# x2             0.1986      0.029      6.855      0.000       0.142       0.255
# x3             0.1331      0.033      4.027      0.000       0.068       0.198
# x4             0.1004      0.012      8.686      0.000       0.078       0.123
# x5             0.1608      0.058      2.755      0.006       0.046       0.275
# x6             0.1575      0.051      3.109      0.002       0.058       0.257
# x7             0.2174      0.023      9.474      0.000       0.172       0.262
# x8             0.1336      0.025      5.276      0.000       0.084       0.183
# x9            -0.0248      0.090     -0.275      0.783      -0.202       0.152
# ==============================================================================
# Omnibus:                      891.599   Durbin-Watson:                   0.302
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.864
# Skew:                           0.147   Prob(JB):                     5.05e-20
# Kurtosis:                       1.833   Cond. No.                         141.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_opt = X[:,[0,1,2,3,4,5,6,7]]
regressor_OLS = sm.OLS(endog = Y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     959.8
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):               0.00
# Time:                        17:58:49   Log-Likelihood:                -1840.2
# No. Observations:                1472   AIC:                             3696.
# Df Residuals:                    1464   BIC:                             3739.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0188      0.003     -6.559      0.000      -0.024      -0.013
# x2             0.1997      0.029      6.963      0.000       0.143       0.256
# x3             0.1332      0.033      4.031      0.000       0.068       0.198
# x4             0.1004      0.012      8.690      0.000       0.078       0.123
# x5             0.1597      0.058      2.744      0.006       0.046       0.274
# x6             0.1572      0.051      3.106      0.002       0.058       0.257
# x7             0.2167      0.023      9.497      0.000       0.172       0.261
# x8             0.1345      0.025      5.357      0.000       0.085       0.184
# ==============================================================================
# Omnibus:                      904.334   Durbin-Watson:                   0.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.197
# Skew:                           0.147   Prob(JB):                     4.28e-20
# Kurtosis:                       1.831   Cond. No.                         93.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_opt = X[:,[0,1,2,3,5,6,7]]
regressor_OLS = sm.OLS(endog = Y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     1091.
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):               0.00
# Time:                        17:58:49   Log-Likelihood:                -1844.0
# No. Observations:                1472   AIC:                             3702.
# Df Residuals:                    1465   BIC:                             3739.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0182      0.003     -6.347      0.000      -0.024      -0.013
# x2             0.1971      0.029      6.860      0.000       0.141       0.253
# x3             0.1481      0.033      4.535      0.000       0.084       0.212
# x4             0.1035      0.012      8.977      0.000       0.081       0.126
# x5             0.1772      0.050      3.529      0.000       0.079       0.276
# x6             0.2365      0.022     10.894      0.000       0.194       0.279
# x7             0.1350      0.025      5.367      0.000       0.086       0.184
# ==============================================================================
# Omnibus:                      752.695   Durbin-Watson:                   0.317
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.924
# Skew:                           0.153   Prob(JB):                     2.20e-19
# Kurtosis:                       1.857   Cond. No.                         79.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
